# %% [markdown]
# <a href="https://colab.research.google.com/github/cuoicungtui/notebook-example-LLM/blob/master/openparse_quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openparse[ml]
# !mkdir -p sample-docs
# !wget https://sergey-filimonov.nyc3.digitaloceanspaces.com/open-parse/sample-docs/naic-numerical-list-of-companies-page-94.pdf -O sample-docs/companies-list.pdf
# !wget https://sergey-filimonov.nyc3.digitaloceanspaces.com/open-parse/sample-docs/mobile-home-manual.pdf -O sample-docs/mobile-home-manual.pdf
# !wget https://sergey-filimonov.nyc3.digitaloceanspaces.com/open-parse/sample-docs/meta-2022-10k-page-69.pdf -O sample-docs/meta-10k.pdf
# Out:
# Collecting openparse[ml]
#   Downloading openparse-0.5.0-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.4/94.4 kB 1.8 MB/s eta 0:00:00
# Collecting PyMuPDF>=1.23.2 (from openparse[ml])
#   Downloading PyMuPDF-1.24.1-cp310-none-manylinux2014_x86_64.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=8.3 in /usr/local/lib/python3.10/dist-packages (from openparse[ml]) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from openparse[ml]) (2.6.4)
# Collecting pypdf>=4.0.0 (from openparse[ml])
#   Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 9.8 MB/s eta 0:00:00
# Collecting pdfminer.six>=20200401 (from openparse[ml])
#   Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 16.6 MB/s eta 0:00:00
# Collecting tiktoken>=0.3 (from openparse[ml])
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.8 MB/s eta 0:00:00
# Collecting openai>=1.0.0 (from openparse[ml])
#   Downloading openai-1.16.2-py3-none-any.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openparse[ml]) (1.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openparse[ml]) (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from openparse[ml]) (0.17.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from openparse[ml]) (4.38.2)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (from openparse[ml]) (0.15.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.0.0->openparse[ml]) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.0.0->openparse[ml]) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai>=1.0.0->openparse[ml])
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.0.0->openparse[ml]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>=1.0.0->openparse[ml]) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai>=1.0.0->openparse[ml]) (4.10.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six>=20200401->openparse[ml]) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six>=20200401->openparse[ml]) (42.0.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->openparse[ml]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->openparse[ml]) (2.16.3)
# Collecting PyMuPDFb==1.24.1 (from PyMuPDF>=1.23.2->openparse[ml])
#   Downloading PyMuPDFb-1.24.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken>=0.3->openparse[ml]) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken>=0.3->openparse[ml]) (2.31.0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers->openparse[ml]) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->openparse[ml]) (3.13.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openparse[ml]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openparse[ml]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openparse[ml]) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openparse[ml]) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->openparse[ml])
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 19.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->openparse[ml])
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 39.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->openparse[ml])
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 56.7 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->openparse[ml])
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->openparse[ml])
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.2 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->openparse[ml])
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->openparse[ml])
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.8 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->openparse[ml])
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.6 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->openparse[ml])
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.2 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->openparse[ml])
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->openparse[ml])
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->openparse[ml]) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->openparse[ml])
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->openparse[ml]) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->openparse[ml]) (6.0.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->openparse[ml]) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.0.0->openparse[ml]) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.0.0->openparse[ml]) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six>=20200401->openparse[ml]) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.0.0->openparse[ml]) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.0.0->openparse[ml])
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.7 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0.0->openparse[ml])
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken>=0.3->openparse[ml]) (2.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openparse[ml]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openparse[ml]) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six>=20200401->openparse[ml]) (2.22)
# Installing collected packages: pypdf, PyMuPDFb, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, h11, tiktoken, PyMuPDF, nvidia-cusparse-cu12, nvidia-cudnn-cu12, httpcore, pdfminer.six, nvidia-cusolver-cu12, httpx, openai, openparse
# Successfully installed PyMuPDF-1.24.1 PyMuPDFb-1.24.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 openai-1.16.2 openparse-0.5.0 pdfminer.six-20231228 pypdf-4.2.0 tiktoken-0.6.0
# --2024-04-08 04:12:25--  https://sergey-filimonov.nyc3.digitaloceanspaces.com/open-parse/sample-docs/naic-numerical-list-of-companies-page-94.pdf
# Resolving sergey-filimonov.nyc3.digitaloceanspaces.com (sergey-filimonov.nyc3.digitaloceanspaces.com)... 162.243.189.2
# Connecting to sergey-filimonov.nyc3.digitaloceanspaces.com (sergey-filimonov.nyc3.digitaloceanspaces.com)|162.243.189.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12281 (12K) [application/pdf]
# Saving to: ‘sample-docs/companies-list.pdf’
#
# sample-docs/compani 100%[===================>]  11.99K  --.-KB/s    in 0s
#
# 2024-04-08 04:12:26 (170 MB/s) - ‘sample-docs/companies-list.pdf’ saved [12281/12281]
#
# --2024-04-08 04:12:26--  https://sergey-filimonov.nyc3.digitaloceanspaces.com/open-parse/sample-docs/mobile-home-manual.pdf
# Resolving sergey-filimonov.nyc3.digitaloceanspaces.com (sergey-filimonov.nyc3.digitaloceanspaces.com)... 162.243.189.2
# Connecting to sergey-filimonov.nyc3.digitaloceanspaces.com (sergey-filimonov.nyc3.digitaloceanspaces.com)|162.243.189.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24123 (24K) [application/pdf]
# Saving to: ‘sample-docs/mobile-home-manual.pdf’
#
# sample-docs/mobile- 100%[===================>]  23.56K  --.-KB/s    in 0s
#
# 2024-04-08 04:12:26 (228 MB/s) - ‘sample-docs/mobile-home-manual.pdf’ saved [24123/24123]
#
# --2024-04-08 04:12:26--  https://sergey-filimonov.nyc3.digitaloceanspaces.com/open-parse/sample-docs/meta-2022-10k-page-69.pdf
# Resolving sergey-filimonov.nyc3.digitaloceanspaces.com (sergey-filimonov.nyc3.digitaloceanspaces.com)... 162.243.189.2
# Connecting to sergey-filimonov.nyc3.digitaloceanspaces.com (sergey-filimonov.nyc3.digitaloceanspaces.com)|162.243.189.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85021 (83K) [application/pdf]
# Saving to: ‘sample-docs/meta-10k.pdf’
#
# sample-docs/meta-10 100%[===================>]  83.03K  --.-KB/s    in 0.08s
#
# 2024-04-08 04:12:27 (1011 KB/s) - ‘sample-docs/meta-10k.pdf’ saved [85021/85021]

# %% [markdown]
# ## 1. Basic Extraction

# %%
import openparse

basic_doc_path = "./sample-docs/mobile-home-manual.pdf"
parser = openparse.DocumentParser()
parsed_basic_doc = parser.parse(basic_doc_path)

for node in parsed_basic_doc.nodes:
    display(node)
# Out:
# Node(elements=(TextElement(text='**RULE 9 - 55 AND RETIRED DISCOUNT**', lines=(LineElement(bbox=(72.05, 695.83, 292.58, 707.83), spans=(TextSpan(text='RULE 9 - 55 AND RETIRED DISCOUNT ', is_bold=True, is_italic=False, size=12.0),), style=None, text='**RULE 9 - 55 AND RETIRED DISCOUNT**'),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=72.05, y0=695.83, x1=292.58, y1=707.83), variant=<NodeVariant.TEXT: 'text'>, embed_text='**RULE 9 - 55 AND RETIRED DISCOUNT**'), TextElement(text='If the following criteria are met, reduce the otherwise applicable Standard or Deluxe Policy \nPackage Premium by 10%. ', lines=(LineElement(bbox=(72.05, 671.83, 542.78, 683.83), spans=(TextSpan(text='If the following criteria are met, reduce the otherwise applicable Standard or Deluxe Policy ', is_bold=False, is_italic=False, size=12.0),), style=None, text='If the following criteria are met, reduce the otherwise applicable Standard or Deluxe Policy '), LineElement(bbox=(72.05, 659.83, 205.0, 671.83), spans=(TextSpan(text='Package Premium by 10%. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='Package Premium by 10%. ')), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=72.05, y0=659.83, x1=542.78, y1=683.83), variant=<NodeVariant.TEXT: 'text'>, embed_text='If the following criteria are met, reduce the otherwise applicable Standard or Deluxe Policy \nPackage Premium by 10%. '), TextElement(text='1. ', lines=(LineElement(bbox=(94.64, 635.81, 106.81, 647.81), spans=(TextSpan(text='1. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='1. '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=94.64, y0=635.81, x1=106.81, y1=647.81), variant=<NodeVariant.TEXT: 'text'>, embed_text='1. '), TextElement(text='One of the Named Insureds must be age 55 or older. ', lines=(LineElement(bbox=(126.07, 635.81, 380.15, 647.81), spans=(TextSpan(text='One of the Named Insureds must be age 55 or older. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='One of the Named Insureds must be age 55 or older. '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=126.07, y0=635.81, x1=380.15, y1=647.81), variant=<NodeVariant.TEXT: 'text'>, embed_text='One of the Named Insureds must be age 55 or older. '), TextElement(text='2. ', lines=(LineElement(bbox=(96.05, 611.81, 108.22, 623.81), spans=(TextSpan(text='2. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='2. '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=96.05, y0=611.81, x1=108.22, y1=623.81), variant=<NodeVariant.TEXT: 'text'>, embed_text='2. '), TextElement(text='Both the Named Insured and Spouse, if any, are not presently gainfully employed full-\ntime or actively seeking full-time gainful employment. ', lines=(LineElement(bbox=(126.07, 611.81, 540.07, 623.81), spans=(TextSpan(text='Both the Named Insured and Spouse, if any, are not presently gainfully employed full-', is_bold=False, is_italic=False, size=12.0),), style=None, text='Both the Named Insured and Spouse, if any, are not presently gainfully employed full-'), LineElement(bbox=(126.07, 599.81, 392.15, 611.81), spans=(TextSpan(text='time or actively seeking full-time gainful employment. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='time or actively seeking full-time gainful employment. ')), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=126.07, y0=599.81, x1=540.07, y1=623.81), variant=<NodeVariant.TEXT: 'text'>, embed_text='Both the Named Insured and Spouse, if any, are not presently gainfully employed full-\ntime or actively seeking full-time gainful employment. '), TextElement(text='3. ', lines=(LineElement(bbox=(96.05, 575.79, 108.22, 587.79), spans=(TextSpan(text='3. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='3. '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=96.05, y0=575.79, x1=108.22, y1=587.79), variant=<NodeVariant.TEXT: 'text'>, embed_text='3. '), TextElement(t ...
# Node(elements=(TextElement(text='**RULE 10 - CLASSIFICATION**', lines=(LineElement(bbox=(72.05, 539.76, 236.79, 551.76), spans=(TextSpan(text='RULE 10 - CLASSIFICATION ', is_bold=True, is_italic=False, size=12.0),), style=None, text='**RULE 10 - CLASSIFICATION**'),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=72.05, y0=539.76, x1=236.79, y1=551.76), variant=<NodeVariant.TEXT: 'text'>, embed_text='**RULE 10 - CLASSIFICATION**'), TextElement(text='Mobile Homes are classified either Class 1 or Class 2. ', lines=(LineElement(bbox=(72.05, 515.76, 335.31, 527.76), spans=(TextSpan(text='Mobile Homes are classified either Class 1 or Class 2. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='Mobile Homes are classified either Class 1 or Class 2. '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=72.05, y0=515.76, x1=335.31, y1=527.76), variant=<NodeVariant.TEXT: 'text'>, embed_text='Mobile Homes are classified either Class 1 or Class 2. '), TextElement(text='1. ', lines=(LineElement(bbox=(96.05, 491.76, 108.22, 503.76), spans=(TextSpan(text='1. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='1. '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=96.05, y0=491.76, x1=108.22, y1=503.76), variant=<NodeVariant.TEXT: 'text'>, embed_text='1. '), TextElement(text='Class 1 rates and premiums apply to owner-occupied one-family Mobile Home which \nmeet the following requirements: ', lines=(LineElement(bbox=(126.07, 491.76, 543.18, 503.76), spans=(TextSpan(text='Class 1 rates and premiums apply to owner-occupied one-family Mobile Home which ', is_bold=False, is_italic=False, size=12.0),), style=None, text='Class 1 rates and premiums apply to owner-occupied one-family Mobile Home which '), LineElement(bbox=(126.07, 479.74, 288.69, 491.74), spans=(TextSpan(text='meet the following requirements: ', is_bold=False, is_italic=False, size=12.0),), style=None, text='meet the following requirements: ')), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=126.07, y0=479.74, x1=543.18, y1=503.76), variant=<NodeVariant.TEXT: 'text'>, embed_text='Class 1 rates and premiums apply to owner-occupied one-family Mobile Home which \nmeet the following requirements: '), TextElement(text='a. ', lines=(LineElement(bbox=(126.07, 455.74, 137.54, 467.74), spans=(TextSpan(text='a. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='a. '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=126.07, y0=455.74, x1=137.54, y1=467.74), variant=<NodeVariant.TEXT: 'text'>, embed_text='a. '), TextElement(text='Principal residence of occupant ', lines=(LineElement(bbox=(156.09, 455.74, 310.22, 467.74), spans=(TextSpan(text='Principal residence of occupant ', is_bold=False, is_italic=False, size=12.0),), style=None, text='Principal residence of occupant '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=156.09, y0=455.74, x1=310.22, y1=467.74), variant=<NodeVariant.TEXT: 'text'>, embed_text='Principal residence of occupant '), TextElement(text='b. ', lines=(LineElement(bbox=(126.07, 431.72, 138.25, 443.72), spans=(TextSpan(text='b. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='b. '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=126.07, y0=431.72, x1=138.25, y1=443.72), variant=<NodeVariant.TEXT: 'text'>, embed_text='b. '), TextElement(text='Used exclusively for residential purposes ', lines=(LineElement(bbox=(156.09, 431.72, 357.19, 443.72), spans=(TextSpan(text='Used exclusively for residential purposes ', is_bold=False, is_italic=False, size=12.0),), style=None, text='Used exclusively for residential purposes '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=156.09, y0=431.72, x1=357.19, y1=443.72), variant=<NodeVariant.TEXT: 'text'>, embed_text='Used exclusively for residential purposes '), TextElement(text='2. ', lines=(LineElement(bbox=(96.05, 407.72, 108.22, 419.72), spans=(TextSpan(text='2. ', is_bold=False,  ...
# Node(elements=(TextElement(text='**RULE 11 - PREMIUM DETERMINATION**', lines=(LineElement(bbox=(72.05, 359.69, 301.75, 371.69), spans=(TextSpan(text='RULE 11 - PREMIUM DETERMINATION ', is_bold=True, is_italic=False, size=12.0),), style=None, text='**RULE 11 - PREMIUM DETERMINATION**'),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=72.05, y0=359.69, x1=301.75, y1=371.69), variant=<NodeVariant.TEXT: 'text'>, embed_text='**RULE 11 - PREMIUM DETERMINATION**'), TextElement(text='The premium calculations should be done in the following order. ', lines=(LineElement(bbox=(72.05, 335.69, 387.21, 347.69), spans=(TextSpan(text='The premium calculations should be done in the following order. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='The premium calculations should be done in the following order. '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=72.05, y0=335.69, x1=387.21, y1=347.69), variant=<NodeVariant.TEXT: 'text'>, embed_text='The premium calculations should be done in the following order. '), TextElement(text='A. Determine the Package Premium for Class 1 Mobile Home from the State Rate Pages \naccording to the Territorial Zone, type of policy, tie down status, deductible, park size, \npremium group, and purchase price. ', lines=(LineElement(bbox=(72.05, 311.67, 542.83, 323.67), spans=(TextSpan(text='A. Determine the Package Premium for Class 1 Mobile Home from the State Rate Pages ', is_bold=False, is_italic=False, size=12.0),), style=None, text='A. Determine the Package Premium for Class 1 Mobile Home from the State Rate Pages '), LineElement(bbox=(96.05, 299.67, 542.78, 311.67), spans=(TextSpan(text='according to the Territorial Zone, type of policy, tie down status, deductible, park size, ', is_bold=False, is_italic=False, size=12.0),), style=None, text='according to the Territorial Zone, type of policy, tie down status, deductible, park size, '), LineElement(bbox=(96.05, 287.67, 272.44, 299.67), spans=(TextSpan(text='premium group, and purchase price. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='premium group, and purchase price. ')), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=72.05, y0=287.67, x1=542.83, y1=323.67), variant=<NodeVariant.TEXT: 'text'>, embed_text='A. Determine the Package Premium for Class 1 Mobile Home from the State Rate Pages \naccording to the Territorial Zone, type of policy, tie down status, deductible, park size, \npremium group, and purchase price. '), TextElement(text='B. Multiply the appropriate Package Premium amount by a Rate Adjustment Factor of 1.398. ', lines=(LineElement(bbox=(72.05, 263.65, 538.72, 275.65), spans=(TextSpan(text='B. Multiply the appropriate Package Premium amount by a Rate Adjustment Factor of 1.398. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='B. Multiply the appropriate Package Premium amount by a Rate Adjustment Factor of 1.398. '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=72.05, y0=263.65, x1=538.72, y1=275.65), variant=<NodeVariant.TEXT: 'text'>, embed_text='B. Multiply the appropriate Package Premium amount by a Rate Adjustment Factor of 1.398. '), TextElement(text='C. Apply the deductible factor, if applicable. ', lines=(LineElement(bbox=(72.05, 239.65, 299.64, 251.65), spans=(TextSpan(text='C. Apply the deductible factor, if applicable. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='C. Apply the deductible factor, if applicable. '),), bbox=Bbox(page=0, page_height=792.0, page_width=612.0, x0=72.05, y0=239.65, x1=299.64, y1=251.65), variant=<NodeVariant.TEXT: 'text'>, embed_text='C. Apply the deductible factor, if applicable. '), TextElement(text='D. Apply the Out-of-Park Surcharge, if applicable. ', lines=(LineElement(bbox=(72.05, 215.65, 328.25, 227.65), spans=(TextSpan(text='D. Apply the Out-of-Park Surcharge, if applicable. ', is_bold=False, is_italic=False, size=12.0),), style=None, text='D. Apply the Out-of-Park Surcha ...

# %%
# you can also easily display the nodes on the actual document

pdf = openparse.Pdf(basic_doc_path)
pdf.display_with_bboxes(
    parsed_basic_doc.nodes,
)

# %% [markdown]
# ## 2. Serialization:
#
# OpenParse returns pydantic models that can easily be serialized

# %%
parsed_basic_doc.model_dump()
# Out:
# {'nodes': [{'variant': {'text'},
#    'tokens': 107,
#    'bbox': [{'page': 0,
#      'page_height': 792.0,
#      'page_width': 612.0,
#      'x0': 72.05,
#      'y0': 575.79,
#      'x1': 542.78,
#      'y1': 707.83}],
#    'text': '**RULE 9 - 55 AND RETIRED DISCOUNT**<br><br>If the following criteria are met, reduce the otherwise applicable Standard or Deluxe Policy \nPackage Premium by 10%. <br><br>1.  One of the Named Insureds must be age 55 or older. <br><br>2. \nBoth the Named Insured and Spouse, if any, are not presently gainfully employed full-\ntime or actively seeking full-time gainful employment. <br><br>3.  The Insured Residence must be the Principal Residence of the Applicant. '},
#   {'variant': {'text'},
#    'tokens': 95,
#    'bbox': [{'page': 0,
#      'page_height': 792.0,
#      'page_width': 612.0,
#      'x0': 72.05,
#      'y0': 395.72,
#      'x1': 543.18,
#      'y1': 551.76}],
#    'text': '**RULE 10 - CLASSIFICATION**<br><br>Mobile Homes are classified either Class 1 or Class 2. <br><br>1. <br><br>Class 1 rates and premiums apply to owner-occupied one-family Mobile Home which \nmeet the following requirements: <br><br>a.  Principal residence of occupant <br><br>b.  Used exclusively for residential purposes <br><br>2. \nAll other mobile homes are Class 2. Premiums are determined by applying the factor \nshown on the Supplementary Rate Page. '},
#   {'variant': {'text'},
#    'tokens': 190,
#    'bbox': [{'page': 0,
#      'page_height': 792.0,
#      'page_width': 612.0,
#      'x0': 72.05,
#      'y0': 90.98,
#      'x1': 542.83,
#      'y1': 371.69}],
#    'text': '**RULE 11 - PREMIUM DETERMINATION**<br><br>The premium calculations should be done in the following order. <br><br>A. Determine the Package Premium for Class 1 Mobile Home from the State Rate Pages \naccording to the Territorial Zone, type of policy, tie down status, deductible, park size, \npremium group, and purchase price. <br><br>B. Multiply the appropriate Package Premium amount by a Rate Adjustment Factor of 1.398. <br><br>C. Apply the deductible factor, if applicable. <br><br>D. Apply the Out-of-Park Surcharge, if applicable. <br><br>E. Apply the original owner discount, if applicable. <br><br>F. Apply the protective device discount, if applicable. <br><br>G. Apply the 55 and retired discount, if applicable. <br><br>H. For Class 2 Mobile Home, apply the Class 2 factor. <br><br>I. Apply The Good Hands People\uf0e2 Discount, if applicable. '}],
#  'filename': 'mobile-home-manual.pdf',
#  'num_pages': 1,
#  'coordinate_system': 'bottom-left',
#  'table_parsing_kwargs': None}

# %% [markdown]
# ## Tables
#
# We aim to be model agnostic - the DocumentParser supports extracting tables using either the "table-transformers" or "pymupdf" libraries - we're model agnostic. The `parsing_algorithm` field in the configuration dictionary decides which one to use.
#
# The `PyMuPDFArgsDict` (and similarly the `TableTransformersArgsDict`) lets you fine-tune how tables are extracted using specific arguments.

# %%
doc_with_tables_path = "./sample-docs/companies-list.pdf"

parser = openparse.DocumentParser(
    table_args={"parsing_algorithm": "table-transformers"}
)
parsed_doc2 = parser.parse(doc_with_tables_path)

for node in parsed_doc2.nodes:
    display(node)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/76.5k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/76.8k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# Node(elements=(TableElement(text='<table border="1">\n<thead>\n<tr>\n<th style="min-width:171px;">GROUP NAME</th>\n<th style="min-width:156px;">GROUP</th>\n<th style="min-width:51px;">CO NO</th>\n<th style="min-width:40px;">STMT</th>\n<th style="min-width:45px;">STATUS</th>\n<th style="min-width:26px;">ST</th>\n<th style="min-width:168px;">COMPANY NAME</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td style="min-width:171px;">CVS GRP</td>\n<td style="min-width:156px;">1</td>\n<td style="min-width:51px;">15827</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">PA</td>\n<td style="min-width:168px;">AETNA HLTH ASSUR PA INC</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;">95935</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">CT</td>\n<td style="min-width:168px;">AETNA HLTH INC CT CORP</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;">95088</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">FL</td>\n<td style="min-width:168px;">AETNA HLTH INC FL CORP</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;">95094</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">GA</td>\n<td style="min-width:168px;">AETNA HLTH INC GA CORP</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;">95517</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">ME</td>\n<td style="min-width:168px;">AETNA HLTH INC ME CORP</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;">95287</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">NJ</td>\n<td style="min-width:168px;">AETNA HLTH INC NJ CORP</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;">95234</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">NY</td>\n<td style="min-width:168px;">AETNA HLTH INC NY CORP</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;">95109</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">PA</td>\n<td style="min-width:168px;">AETNA HLTH INC PA CORP</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;">95490</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">TX</td>\n<td style="min-width:168px;">AETNA HLTH INC TX CORP</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;">72052</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">PA</td>\n<td style="min-width:168px;">AETNA HLTH INS CO</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;">84450</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">NY</td>\n<td style="min-width:168px;">AETNA HLTH INS CO OF NY</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;">95241</td>\n<td style="min-width:40px;">X</td>\n<td style="min-width:45px;">1</td>\n<td style="min-width:26px;">IA</td>\n<td style="min-width:168px;">AETNA HLTH OF IA INC</td>\n</tr>\n<tr>\n<td style="min-width:171px;"></td>\n<td style="min-width:156px;"></td>\n<td style="min-width:51px;"> ...

# %%
pdf = openparse.Pdf(doc_with_tables_path)
pdf.display_with_bboxes(
    parsed_doc2.nodes,
)

# %%
meta10k_path = "./sample-docs/meta-10k.pdf"

parser = openparse.DocumentParser(table_args={"parsing_algorithm": "pymupdf"})
parsed_10k = parser.parse(meta10k_path)

doc = openparse.Pdf(file=meta10k_path)
doc.display_with_bboxes(parsed_10k.nodes)

# %% [markdown]
# ## 3. Custom Processing (Advanced)
#
# While we've chosen sensible defaults, you can add custom processing functions to the `DocumentParser` class to further process the extracted data.
#
# This allows use cases like:
# - Using embeddings to parse nodes split across pages
# - Use GPT-4V to choose which nodes to combine

# %%
from openparse import processing, Node
from typing import List


class CustomCombineTables(processing.ProcessingStep):
    """
    Let's combine tables that are next to each other
    """

    def process(self, nodes: List[Node]) -> List[Node]:
        new_nodes = []
        print("Combining concurrent tables")
        for i in range(len(nodes) - 1):
            if "table" in nodes[i].variant and "table" in nodes[i + 1].variant:
                new_node = nodes[i] + nodes[i + 1]
                new_nodes.append(new_node)
            else:
                new_nodes.append(nodes[i])

        return new_nodes


# copy the default pipeline (or create a new one)
custom_pipeline = processing.BasicIngestionPipeline()
custom_pipeline.append_transform(CustomCombineTables())

parser = openparse.DocumentParser(
    table_args={"parsing_algorithm": "pymupdf"}, processing_pipeline=custom_pipeline
)
custom_10k = parser.parse(meta10k_path)

doc = openparse.Pdf(file=meta10k_path)
doc.display_with_bboxes(custom_10k.nodes)
# Out:
# Combining concurrent tables
